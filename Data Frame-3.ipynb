# %%
#76
import pandas as pd
bond=pd.read_csv("jamesbond.csv")
bond
# Out:
#                                Film  Year           Actor            Director  \
# 0                            Dr. No  1962    Sean Connery       Terence Young
# 1             From Russia with Love  1963    Sean Connery       Terence Young
# 2                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 3                       Thunderball  1965    Sean Connery       Terence Young
# 4                     Casino Royale  1967     David Niven          Ken Hughes
# 5               You Only Live Twice  1967    Sean Connery       Lewis Gilbert
# 6   On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 7              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 8                  Live and Let Die  1973     Roger Moore        Guy Hamilton
# 9       The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# 10             The Spy Who Loved Me  1977     Roger Moore       Lewis Gilbert
# ...

# %%
#77 set index & reset index
bond.set_index(keys='Film')
# Out:
#                                  Year           Actor            Director  \
# Film
# Dr. No                           1962    Sean Connery       Terence Young
# From Russia with Love            1963    Sean Connery       Terence Young
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Thunderball                      1965    Sean Connery       Terence Young
# Casino Royale                    1967     David Niven          Ken Hughes
# You Only Live Twice              1967    Sean Connery       Lewis Gilbert
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# The Man with the Golden Gun      1974     Roger Moore        Guy Hamilton
# The Spy Who Loved Me             1977     Roger Moore       Lewis Gilbert
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# ...

# %%
bond.reset_index(drop=False) #by keeping drop as false it doesn't drop the previous used index i.e film
# Out:
#     index                             Film  Year           Actor  \
# 0       0                           Dr. No  1962    Sean Connery
# 1       1            From Russia with Love  1963    Sean Connery
# 2       2                       Goldfinger  1964    Sean Connery
# 3       3                      Thunderball  1965    Sean Connery
# 4       4                    Casino Royale  1967     David Niven
# 5       5              You Only Live Twice  1967    Sean Connery
# 6       6  On Her Majesty's Secret Service  1969  George Lazenby
# 7       7             Diamonds Are Forever  1971    Sean Connery
# 8       8                 Live and Let Die  1973     Roger Moore
# 9       9      The Man with the Golden Gun  1974     Roger Moore
# 10     10             The Spy Who Loved Me  1977     Roger Moore
# 11     11                        Moonraker  1979     Roger Moore
# 12     12               For Your Eyes Only  1981     Roger Moore
# ...

# %%
#78 retrieve data by index label with .loc[] 
import pandas as pd
bond=pd.read_csv("jamesbond.csv",index_col="Film")
bond.sort_index(inplace=True)
bond.loc["Goldfinger"]
bond.loc["Casino Royale"]
bond.loc["Diamonds Are Forever":"From Russia With Love"]
# Out:
#                       Year           Actor       Director  Box Office  Budget  \
# Film
# Diamonds Are Forever  1971    Sean Connery   Guy Hamilton       442.5    34.7
# Die Another Day       2002  Pierce Brosnan   Lee Tamahori       465.4   154.2
# Dr. No                1962    Sean Connery  Terence Young       448.8     7.0
# For Your Eyes Only    1981     Roger Moore      John Glen       449.4    60.2
#
#                       Bond Actor Salary
# Film
# Diamonds Are Forever                5.8
# Die Another Day                    17.9
# Dr. No                              0.6
# For Your Eyes Only                  NaN

# %%
bond.loc[["Octopussy","Die Another Day"]]
# Out:
#                  Year           Actor      Director  Box Office  Budget  \
# Film
# Octopussy        1983     Roger Moore     John Glen       373.8    53.9
# Die Another Day  2002  Pierce Brosnan  Lee Tamahori       465.4   154.2
#
#                  Bond Actor Salary
# Film
# Octopussy                      7.8
# Die Another Day               17.9

# %%
#79   iloc method
bond=pd.read_csv("jamesbond.csv")
bond.iloc[0]
bond.iloc[0:]
bond.iloc[[0,1,5,10]]
bond.iloc[[0,1]]
bond.iloc[0:5]
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
# 3            Thunderball  1965  Sean Connery  Terence Young       848.1
# 4          Casino Royale  1967   David Niven     Ken Hughes       315.0
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2
# 3    41.9                4.7
# 4    85.0                NaN

# %%
#80 passing second argument to loc & iloc method
bond=pd.read_csv("jamesbond.csv",index_col="Film")
bond.sort_index(inplace=True)
bond.loc['Moonraker']
bond.loc['Moonraker',['Director','Box Office',"Budget"]]
bond.loc['Moonraker':"Thunderball",'Director':'Box Office']
#bond.loc[['Moonraker','A view to a Kill'],['Director','Box Office']] #This is no longer supprted
# Out:
#                                        Director  Box Office
# Film
# Moonraker                         Lewis Gilbert       535.0
# Never Say Never Again            Irvin Kershner       380.0
# Octopussy                             John Glen       373.8
# On Her Majesty's Secret Service   Peter R. Hunt       291.5
# Quantum of Solace                  Marc Forster       514.2
# Skyfall                              Sam Mendes       943.5
# Spectre                              Sam Mendes       726.7
# The Living Daylights                  John Glen       313.5
# The Man with the Golden Gun        Guy Hamilton       334.0
# The Spy Who Loved Me              Lewis Gilbert       533.0
# The World Is Not Enough           Michael Apted       439.5
# Thunderball                       Terence Young       848.1

# %%
#81 set new value for a cell 
bond=bond.sort_index()
bond.loc['Dr. No','Actor']='Eric' #previously it was Sean Connery but now we assigned Eric
bond.loc['Dr. No','Actor']
# Out:
# 'Eric'

# %%
bond.loc['Dr. No',['Actor','Budget']]=['Eric',10000]#previously they are different values but now changed to nagarjuna & 1000
bond.loc[['Dr. No'],['Actor','Budget']] #it changed the values in the cell
# Out:
#        Actor   Budget
# Film
# Dr. No  Eric  10000.0

# %%
bond=bond.sort_index()
bond.loc['Dr. No',['Actor','Budget']]
# Out:
# Actor     Nagarjuna
# Budget        10000
# Name: Dr. No, dtype: object

# %%
#83 Rename index labels in a DatafRame
bond.rename(mapper={"GoldenEye":"Golden Eye","The World Is Not Enough":"Best Bond Movie Ever"})
#Another method to rename
#bond.rename(index={"GoldenEye":"Golden Eye","The World Is Not Enough":"Best Bond Movie Ever"})
# Out:
#                                  Year           Actor            Director  \
# Film
# A View to a Kill                 1985     Roger Moore           John Glen
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962            Eric       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# From Russia with Love            1963    Sean Connery       Terence Young
# Golden Eye                       1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# ...

# %%
#Rename column names in  a DataFrame
bond.rename(mapper={"Year":"Release Date","Box Office":"Revenue"},axis="columns")
# Out:
#                                  Release Date           Actor  \
# Film
# A View to a Kill                         1985     Roger Moore
# Casino Royale                            2006    Daniel Craig
# Casino Royale                            1967     David Niven
# Diamonds Are Forever                     1971    Sean Connery
# Die Another Day                          2002  Pierce Brosnan
# Dr. No                                   1962            Eric
# For Your Eyes Only                       1981     Roger Moore
# From Russia with Love                    1963    Sean Connery
# GoldenEye                                1995  Pierce Brosnan
# Goldfinger                               1964    Sean Connery
# Licence to Kill                          1989  Timothy Dalton
# Live and Let Die                         1973     Roger Moore
# Moonraker                                1979     Roger Moore
# Never Say Never Again                    1983    Sean Connery
# ...

# %%
#Delete Rows or columns from a DataFrame
bond.drop(["A View to a Kill","Casino Royale"]) #it drops the rows
# Out:
#                                  Year           Actor            Director  \
# Film
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962            Eric       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# From Russia with Love            1963    Sean Connery       Terence Young
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# Never Say Never Again            1983    Sean Connery      Irvin Kershner
# Octopussy                        1983     Roger Moore           John Glen
# ...

# %%
bond.drop(["Box Office","Actor"],axis="columns")
#del bond["Director"]
# Out:
#                                  Year            Director   Budget  \
# Film
# A View to a Kill                 1985           John Glen     54.5
# Casino Royale                    2006     Martin Campbell    145.3
# Casino Royale                    1967          Ken Hughes     85.0
# Diamonds Are Forever             1971        Guy Hamilton     34.7
# Die Another Day                  2002        Lee Tamahori    154.2
# Dr. No                           1962       Terence Young  10000.0
# For Your Eyes Only               1981           John Glen     60.2
# From Russia with Love            1963       Terence Young     12.6
# GoldenEye                        1995     Martin Campbell     76.9
# Goldfinger                       1964        Guy Hamilton     18.6
# Licence to Kill                  1989           John Glen     56.7
# Live and Let Die                 1973        Guy Hamilton     30.8
# Moonraker                        1979       Lewis Gilbert     91.5
# ...

# %%
#85 creating ramdon sample with sample method
bond.sample(n=5) #extracts 5 rows
# Out:
#                                  Year           Actor            Director  \
# Film
# From Russia with Love            1963    Sean Connery       Terence Young
# Tomorrow Never Dies              1997  Pierce Brosnan  Roger Spottiswoode
# For Your Eyes Only               1981     Roger Moore           John Glen
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# The Spy Who Loved Me             1977     Roger Moore       Lewis Gilbert
#
#                                  Box Office  Budget  Bond Actor Salary
# Film
# From Russia with Love                 543.8    12.6                1.6
# Tomorrow Never Dies                   463.2   133.9               10.0
# For Your Eyes Only                    449.4    60.2                NaN
# On Her Majesty's Secret Service       291.5    37.3                0.6
# The Spy Who Loved Me                  533.0    45.1                NaN

# %%
bond.sample(n=3,axis="columns") #extracts 3 columns
# Out:
#                                   Budget            Director  Box Office
# Film
# A View to a Kill                    54.5           John Glen       275.2
# Casino Royale                      145.3     Martin Campbell       581.5
# Casino Royale                       85.0          Ken Hughes       315.0
# Diamonds Are Forever                34.7        Guy Hamilton       442.5
# Die Another Day                    154.2        Lee Tamahori       465.4
# Dr. No                           10000.0       Terence Young       448.8
# For Your Eyes Only                  60.2           John Glen       449.4
# From Russia with Love               12.6       Terence Young       543.8
# GoldenEye                           76.9     Martin Campbell       518.5
# Goldfinger                          18.6        Guy Hamilton       820.4
# Licence to Kill                     56.7           John Glen       250.9
# Live and Let Die                    30.8        Guy Hamilton       460.3
# ...

# %%
bond.sample(frac=0.25)#extracts 25% of the sample
# Out:
#                        Year           Actor        Director  Box Office  \
# Film
# A View to a Kill       1985     Roger Moore       John Glen       275.2
# Skyfall                2012    Daniel Craig      Sam Mendes       943.5
# Never Say Never Again  1983    Sean Connery  Irvin Kershner       380.0
# Octopussy              1983     Roger Moore       John Glen       373.8
# Die Another Day        2002  Pierce Brosnan    Lee Tamahori       465.4
# Live and Let Die       1973     Roger Moore    Guy Hamilton       460.3
#
#                        Budget  Bond Actor Salary
# Film
# A View to a Kill         54.5                9.1
# Skyfall                 170.2               14.5
# Never Say Never Again    86.0                NaN
# Octopussy                53.9                7.8
# Die Another Day         154.2               17.9
# Live and Let Die         30.8                NaN

# %%
# nlargest & nsmallest
bond.nlargest(3,columns="Box Office")
bond.nsmallest(3,columns="Box Office")
#Another method
#bond["Box Office"].nlargest(n=5)
# Out:
#                                  Year           Actor       Director  \
# Film
# Licence to Kill                  1989  Timothy Dalton      John Glen
# A View to a Kill                 1985     Roger Moore      John Glen
# On Her Majesty's Secret Service  1969  George Lazenby  Peter R. Hunt
#
#                                  Box Office  Budget  Bond Actor Salary
# Film
# Licence to Kill                       250.9    56.7                7.9
# A View to a Kill                      275.2    54.5                9.1
# On Her Majesty's Secret Service       291.5    37.3                0.6

# %%
# where method
bond.where(bond["Box Office"]>8000)
# Out:
#                                  Year Actor Director  Box Office  Budget  \
# Film
# A View to a Kill                  NaN   NaN      NaN         NaN     NaN
# Casino Royale                     NaN   NaN      NaN         NaN     NaN
# Casino Royale                     NaN   NaN      NaN         NaN     NaN
# Diamonds Are Forever              NaN   NaN      NaN         NaN     NaN
# Die Another Day                   NaN   NaN      NaN         NaN     NaN
# Dr. No                            NaN   NaN      NaN         NaN     NaN
# For Your Eyes Only                NaN   NaN      NaN         NaN     NaN
# From Russia with Love             NaN   NaN      NaN         NaN     NaN
# GoldenEye                         NaN   NaN      NaN         NaN     NaN
# Goldfinger                        NaN   NaN      NaN         NaN     NaN
# Licence to Kill                   NaN   NaN      NaN         NaN     NaN
# Live and Let Die                  NaN   NaN      NaN         NaN     NaN
# ...

# %%
bond.query('Actor=="Sean Connery"')
bond.query('Director=="Terence Young"')
bond.query("Actor=='Sean Connery' and Director=='Terence Young'")
#bond.query("Box Office > 200")
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Thunderball            1965  Sean Connery  Terence Young       848.1    41.9
#
#                        Bond Actor Salary
# Film
# From Russia with Love                1.6
# Thunderball                          4.7

# %%
bond.query("Actor in ['Sean Connery','George Lazenby']")
# Out:
#                                  Year           Actor        Director  \
# Film
# Diamonds Are Forever             1971    Sean Connery    Guy Hamilton
# From Russia with Love            1963    Sean Connery   Terence Young
# Goldfinger                       1964    Sean Connery    Guy Hamilton
# Never Say Never Again            1983    Sean Connery  Irvin Kershner
# On Her Majesty's Secret Service  1969  George Lazenby   Peter R. Hunt
# Thunderball                      1965    Sean Connery   Terence Young
# You Only Live Twice              1967    Sean Connery   Lewis Gilbert
#
#                                  Box Office  Budget  Bond Actor Salary
# Film
# Diamonds Are Forever                  442.5    34.7                5.8
# From Russia with Love                 543.8    12.6                1.6
# Goldfinger                            820.4    18.6                3.2
# Never Say Never Again                 380.0    86.0                NaN
# ...
